# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Nombre del archivo pickle
nombre_archivo_binario = 'datos_imagenes.pkl'

# Cargar el DataFrame desde el archivo pickle
df_imagenes = pd.read_pickle(nombre_archivo_binario)

# Ahora puedes trabajar con el DataFrame cargado
print(df_imagenes.head(1))
# Out:
#                                               Imagen Etiqueta  \
# 0  [[[165, 165, 163], [165, 165, 163], [165, 166,...    bored
#
#                  Rostro                                          Landmarks
# 0  (202, 408, 356, 253)  {'chin': [(268, 262), (268, 279), (270, 295), ...

# %%
# Obtener la primera imagen del DataFrame
imagen_primera = df_imagenes['Imagen'][0]

# Mostrar la imagen utilizando Matplotlib
plt.imshow(imagen_primera)
plt.axis('off')  # Desactivar los ejes
plt.show()
