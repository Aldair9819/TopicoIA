# %% [markdown]
# Importamos Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
import subprocess
from keras.layers import Input, Flatten, Dense
from keras.models import Model
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-05-15 10:28:35.193505: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-15 10:28:35.963286: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Usar la VRAM necesaria de la GPU

# %%
def get_gpu_memory():
    """Returns the total memory of the GPU in MB"""
    try:
        result = subprocess.check_output(
            ["nvidia-smi", "--query-gpu=memory.total", "--format=csv,nounits,noheader"], 
            encoding='utf-8')
        return int(result.strip())
    except Exception as e:
        print("Error al obtener la información de la memoria de la GPU:", e)
        return None

# Obtener la cantidad de memoria VRAM disponible en la GPU
total_memory_mb = get_gpu_memory()
if total_memory_mb is not None:
    total_memory_gb = total_memory_mb / 1024
    print("Cantidad total de memoria VRAM en la GPU:", total_memory_gb, "GB")
    
    # Configurar TensorFlow para limitar el uso de memoria GPU
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            # Limitar la memoria GPU al máximo disponible
            tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("No se pudo obtener la información de la memoria de la GPU.")
# Out:
# Cantidad total de memoria VRAM en la GPU: 6.0 GB
# 2024-05-15 10:28:36.612546: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:36.661672: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:36.661948: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# Cargar la base de datos, en formato HDF5

# %%
df = pd.read_hdf('BD_Emotions_3.h5')

# %% [markdown]
# Revisión de los datos.

# %%
df.head()
# Out:
#                                               Imagen  \
# 0  [[154, 157, 156, 157, 158, 159, 157, 157, 159,...
# 1  [[156, 155, 156, 156, 159, 156, 156, 157, 158,...
# 2  [[172, 171, 173, 171, 172, 172, 173, 172, 172,...
# 3  [[171, 168, 168, 170, 171, 169, 169, 170, 170,...
# 4  [[180, 181, 181, 181, 183, 182, 181, 182, 182,...
#
#                                      Caracteristicas  \
# 0  [[59, 64], [59, 72], [61, 80], [62, 88], [64, ...
# 1  [[57, 63], [58, 71], [59, 79], [60, 87], [62, ...
# 2  [[60, 81], [60, 90], [61, 98], [62, 106], [64,...
# 3  [[62, 86], [62, 92], [64, 97], [65, 102], [67,...
# 4  [[58, 75], [59, 82], [60, 89], [62, 96], [64, ...
#
#                                               Rostro Etiqueta
# 0  [[167, 166, 166, 18, 14, 35, 102, 18, 24, 39, ...  excited
# 1  [[167, 151, 9, 12, 107, 112, 19, 30, 40, 42, 8...  excited
# 2  [[51, 5, 8, 81, 100, 105, 104, 107, 111, 123, ...  excited
# 3  [[16, 15, 12, 17, 23, 36, 84, 121, 132, 141, 1...  excited
# 4  [[4, 5, 9, 25, 85, 107, 119, 126, 130, 134, 13...  excited

# %% [markdown]
# Retiramos cualquier dato de caracteristicas que pudiera dar un error o que no cumple con las caracteristicas deseadas. Vemos si tiene un formato Standard y ponemos que elimine todas las que no cumplan con ese Standard

# %%
print(df['Caracteristicas'][0].shape)

# Convertir la columna 'Hitos faciales válidos' en un array NumPy
puntos = np.array(df['Caracteristicas'].tolist())

# Verificar la forma de X
print(puntos.shape)
# Out:
# (72, 2)
# (4623, 72, 2)

# %% [markdown]
# Pasamos las etiquetas a forma numerica, con lo cual caen en categorías numericas.

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['Etiqueta'])

# %%
print(y)
# Out:
# [2 2 2 ... 0 0 0]

# %% [markdown]
# Verificación de los datos anteriores, donde vemos la forma de la categoría

# %%
print("Clases originales:", df['Etiqueta'].unique())
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases originales: ['excited' 'engaged' 'bored']
# Clases codificadas: ['bored' 'engaged' 'excited']

# %% [markdown]
# Dividimos los datos para entrenar y para verificar la red MLP

# %%
X_train, X_test, y_train, y_test = train_test_split(puntos, y, test_size=0.3,random_state=42)

# %%
# Convertir las etiquetas a formato one-hot
y_train_one_hot = to_categorical(y_train)
y_val_one_hot = to_categorical(y_test)
clases_originales = df['Etiqueta'].unique()
print(y_val_one_hot)
print("Clases originales:", df['Etiqueta'].unique())
# Out:
# [[0. 0. 1.]
#  [0. 0. 1.]
#  [0. 1. 0.]
#  ...
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [0. 1. 0.]]
# Clases originales: ['excited' 'engaged' 'bored']

# %% [markdown]
# Creacion del modelo, la cantidad de capas es alta para intentar conseguir un accuracy alto, pero como los datos no son proporcionales la complejidad juega en su contra, por lo que ponerle menos capas ayuda a que tenga más accuracy

# %%
# Definir la entrada del modelo
inputs = Input(shape=(72, 2))

# Aplanar los datos de entrada
flatten = Flatten()(inputs)

# Capas densas

dense1 = Dense(600, activation='relu')(flatten)
dense2 = Dense(300, activation='relu')(dense1)
dense3 = Dense(150, activation='relu')(dense2)
dense4 = Dense(75, activation='relu')(dense3)
dense5 = Dense(37, activation='relu')(dense4)


# Capa de salida
outputs = Dense(len(label_encoder.classes_), activation='softmax')(dense5)

model = Model(inputs=inputs, outputs=outputs)

#optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2024-05-15 10:28:38.846364: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:38.846698: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:38.846881: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:38.913749: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:38.913963: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:38.914145: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-15 10:28:38.914283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2652 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# Definir Early Stopping
#early_stopping = EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True)

# %% [markdown]
# Entrenamos el modelo.

# %%
with tf.device('/device:GPU:0'):
    history = model.fit(X_train, y_train_one_hot, epochs=100, batch_size=
100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4447 - loss: 1.0270 - val_accuracy: 0.4568 - val_loss: 1.0209
# Epoch 75/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4468 - loss: 1.0279 - val_accuracy: 0.4537 - val_loss: 1.0306
# Epoch 76/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4382 - loss: 1.0322 - val_accuracy: 0.4012 - val_loss: 1.0310
# Epoch 77/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4525 - loss: 1.0200 - val_accuracy: 0.4630 - val_loss: 1.0241
# Epoch 78/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4491 - loss: 1.0212 - val_accuracy: 0.4012 - val_loss: 1.0498
# Epoch 79/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4555 - loss: 1.0317 - val_accuracy: 0.4537 - val_loss: 1.0298
# Epoch 80/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4453 - loss: 1.0238 - val_accuracy: 0.4660 - val_loss: 1.0168
# Epoch 81/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4352 - loss: 1.0223 - val_accuracy: 0.4599 - val_loss: 1.0279
# Epoch 82/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4403 - loss: 1.0269 - val_accuracy: 0.4012 - val_loss: 1.0317
# Epoch 83/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4352 - loss: 1.0225 - val_accuracy: 0.4537 - val_loss: 1.0207
# Epoch 84/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4558 - loss: 1.0201 - val_accuracy: 0.4352 - val_loss: 1.0189
# Epoch 85/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4697 - loss: 1.0172 - val_accuracy: 0.4383 - val_loss: 1.0255
# Epoch 86/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4743 - loss: 1.0210 - val_accuracy: 0.4630 - val_loss: 1.0142
# Epoch 87/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4655 - loss: 1.0091 - val_accuracy: 0.4444 - val_loss: 1.0136
# Epoch 88/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4606 - loss: 1.0214 - val_accuracy: 0.4414 - val_loss: 1.0123
# Epoch 89/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4605 - loss: 1.0183 - val_accuracy: 0.4414 - val_loss: 1.0158
# Epoch 90/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4639 - loss: 1.0165 - val_accuracy: 0.4105 - val_loss: 1.0452
# Epoch 91/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4383 - loss: 1.0239 - val_accuracy: 0.3951 - val_loss: 1.0365
# Epoch 92/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4541 - loss: 1.0202 - val_accuracy: 0.4599 - val_loss: 1.0172
# Epoch 93/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4582 - loss: 1.0259 - val_accuracy: 0.4444 - val_loss: 1.0226
# Epoch 94/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4566 - loss: 1.0134 - val_accuracy: 0.4444 - val_loss: 1.0254
# Epoch 95/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4524 - loss: 1.0188 - val_accuracy: 0.4568 - val_loss: 1.0115
# Epoch 96/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4751 - loss: 1.0202 - val_accuracy: 0.4414 - val_loss: 1.0132
# Epoch 97/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4538 - loss: 1.0226 - val_accuracy: 0.4506 - val_loss: 1.0124
# Epoch 98/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4731 - loss: 1.0029 - val_accuracy: 0.4414 - val_loss: 1.0246
# Epoch 99/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4357 - loss: 1.0212 - val_accuracy: 0.4444 - val_loss: 1.0123
# Epoch 100/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4415 - loss: 1.0274 - val_accuracy: 0.4043 - val_loss: 1.0401
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4186 - loss: 1.0499
# Best Loss: 1.0351362228393555, Best Accuracy: 0.4167267382144928

# %%
print(f'Best Loss: {best_loss}, Best Accuracy: {best_accuracy}')
# Out:
# Best Loss: 1.0351362228393555, Best Accuracy: 0.4167267382144928

# %% [markdown]
# Checamos como está distribuido los datos. Esto hay que tenerlo en cuenta, dado que esta base de datos solo servirá para Engaged, Excited o Bored. El resto tendrá problemas grandes en localizarlo

# %%
# Obtener las predicciones del conjunto de validación
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# Mostrar la precisión y pérdida del modelo
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Precisión del Modelo')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Pérdida del Modelo')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
# 7. Evaluar el modelo en el conjunto de pruebas
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step

# %%
# Calcular la precisión del modelo
accuracy = accuracy_score(y_test, y_pred_classes)
print("Precisión del modelo en el conjunto de pruebas:", accuracy)

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Mostrar la matriz de confusión de forma gráfica
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Verdadera')
plt.title('Matriz de Confusión')
plt.show()
print(label_encoder.classes_)
# Out:
# Precisión del modelo en el conjunto de pruebas: 0.4167267483777938
# ['bored' 'engaged' 'excited']

# %% [markdown]
# Guardamos el modelo.

# %%
# Guardar el modelo
best_model.save('modelo_mlp_NoEstratificado.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
