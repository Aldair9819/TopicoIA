# %% [markdown]
# Importamos Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
import subprocess
from keras.layers import Input, Flatten, Dense
from keras.models import Model
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Usar la VRAM necesaria de la GPU

# %%
def get_gpu_memory():
    """Returns the total memory of the GPU in MB"""
    try:
        result = subprocess.check_output(
            ["nvidia-smi", "--query-gpu=memory.total", "--format=csv,nounits,noheader"], 
            encoding='utf-8')
        return int(result.strip())
    except Exception as e:
        print("Error al obtener la información de la memoria de la GPU:", e)
        return None

# Obtener la cantidad de memoria VRAM disponible en la GPU
total_memory_mb = get_gpu_memory()
if total_memory_mb is not None:
    total_memory_gb = total_memory_mb / 1024
    print("Cantidad total de memoria VRAM en la GPU:", total_memory_gb, "GB")
    
    # Configurar TensorFlow para limitar el uso de memoria GPU
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            # Limitar la memoria GPU al máximo disponible
            tf.config.experimental.set_memory_growth(gpu, True)
else:
    print("No se pudo obtener la información de la memoria de la GPU.")
# Out:
# Cantidad total de memoria VRAM en la GPU: 6.0 GB

# %% [markdown]
# Cargar la base de datos, en formato HDF5

# %%
df = pd.read_hdf('BD_Emotions_3.h5')

# %% [markdown]
# Revisión de los datos.

# %%
df.head()
# Out:
#                                               Imagen  \
# 0  [[154, 157, 156, 157, 158, 159, 157, 157, 159,...
# 1  [[156, 155, 156, 156, 159, 156, 156, 157, 158,...
# 2  [[172, 171, 173, 171, 172, 172, 173, 172, 172,...
# 3  [[171, 168, 168, 170, 171, 169, 169, 170, 170,...
# 4  [[180, 181, 181, 181, 183, 182, 181, 182, 182,...
#
#                                      Caracteristicas  \
# 0  [[59, 64], [59, 72], [61, 80], [62, 88], [64, ...
# 1  [[57, 63], [58, 71], [59, 79], [60, 87], [62, ...
# 2  [[60, 81], [60, 90], [61, 98], [62, 106], [64,...
# 3  [[62, 86], [62, 92], [64, 97], [65, 102], [67,...
# 4  [[58, 75], [59, 82], [60, 89], [62, 96], [64, ...
#
#                                               Rostro Etiqueta
# 0  [[167, 166, 166, 18, 14, 35, 102, 18, 24, 39, ...  excited
# 1  [[167, 151, 9, 12, 107, 112, 19, 30, 40, 42, 8...  excited
# 2  [[51, 5, 8, 81, 100, 105, 104, 107, 111, 123, ...  excited
# 3  [[16, 15, 12, 17, 23, 36, 84, 121, 132, 141, 1...  excited
# 4  [[4, 5, 9, 25, 85, 107, 119, 126, 130, 134, 13...  excited

# %% [markdown]
# Retiramos cualquier dato de caracteristicas que pudiera dar un error o que no cumple con las caracteristicas deseadas. Vemos si tiene un formato Standard y ponemos que elimine todas las que no cumplan con ese Standard

# %%
print(df['Caracteristicas'][0].shape)

# Convertir la columna 'Hitos faciales válidos' en un array NumPy
puntos = np.array(df['Caracteristicas'].tolist())

# Verificar la forma de X
print(puntos.shape)
# Out:
# (72, 2)
# (4623, 72, 2)

# %% [markdown]
# Pasamos las etiquetas a forma numerica, con lo cual caen en categorías numericas.

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['Etiqueta'])

# %%
print(y)
# Out:
# [2 2 2 ... 0 0 0]

# %% [markdown]
# Verificación de los datos anteriores, donde vemos la forma de la categoría

# %%
print("Clases originales:", df['Etiqueta'].unique())
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases originales: ['excited' 'engaged' 'bored']
# Clases codificadas: ['bored' 'engaged' 'excited']

# %% [markdown]
# Dividimos los datos para entrenar y para verificar la red MLP

# %%
X_train, X_test, y_train, y_test = train_test_split(puntos, y, test_size=0.3, stratify = y,random_state=42)

# %%
# Convertir las etiquetas a formato one-hot
y_train_one_hot = to_categorical(y_train)
y_val_one_hot = to_categorical(y_test)
clases_originales = df['Etiqueta'].unique()
print(y_val_one_hot)
print("Clases originales:", df['Etiqueta'].unique())
# Out:
# [[0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]
#  ...
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]
# Clases originales: ['excited' 'engaged' 'bored']

# %% [markdown]
# Creacion del modelo, la cantidad de capas es alta para intentar conseguir un accuracy alto, pero como los datos no son proporcionales la complejidad juega en su contra, por lo que ponerle menos capas ayuda a que tenga más accuracy

# %%
# Definir la entrada del modelo
inputs = Input(shape=(72, 2))

# Aplanar los datos de entrada
flatten = Flatten()(inputs)

# Capas densas

dense1 = Dense(600, activation='relu')(flatten)
dense2 = Dense(300, activation='relu')(dense1)
dense3 = Dense(150, activation='relu')(dense2)
dense4 = Dense(75, activation='relu')(dense3)
dense5 = Dense(37, activation='relu')(dense4)


# Capa de salida
outputs = Dense(len(label_encoder.classes_), activation='softmax')(dense5)

model = Model(inputs=inputs, outputs=outputs)

#optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Definir Early Stopping
#early_stopping = EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True)

# %% [markdown]
# Entrenamos el modelo.

# %%
with tf.device('/device:GPU:0'):
    history = model.fit(X_train, y_train_one_hot, epochs=80, batch_size=32, validation_split=0.1, 
                        #callbacks=[early_stopping]
                        )

best_loss, best_accuracy = model.evaluate(X_test, y_val_one_hot)
best_model = model
print(f'Best Loss: {best_loss}, Best Accuracy: {best_accuracy}')
# Out:
# Epoch 1/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3457 - loss: 9.2704 - val_accuracy: 0.3827 - val_loss: 1.1039
# Epoch 2/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4064 - loss: 1.2831 - val_accuracy: 0.3796 - val_loss: 1.3059
# Epoch 3/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4072 - loss: 1.1741 - val_accuracy: 0.4167 - val_loss: 1.4194
# Epoch 4/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3895 - loss: 1.2166 - val_accuracy: 0.4167 - val_loss: 1.0685
# Epoch 5/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4261 - loss: 1.0942 - val_accuracy: 0.3889 - val_loss: 1.1488
# Epoch 6/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4315 - loss: 1.1030 - val_accuracy: 0.3704 - val_loss: 1.1102
# Epoch 7/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4305 - loss: 1.0959 - val_accuracy: 0.4259 - val_loss: 1.0315
# Epoch 8/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4190 - loss: 1.0582 - val_accuracy: 0.4722 - val_loss: 1.0200
# Epoch 9/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4041 - loss: 1.0733 - val_accuracy: 0.4228 - val_loss: 1.0339
# Epoch 10/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4399 - loss: 1.0289 - val_accuracy: 0.4167 - val_loss: 1.0569
# Epoch 11/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4455 - loss: 1.0402 - val_accuracy: 0.4383 - val_loss: 1.0284
# Epoch 12/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4249 - loss: 1.0488 - val_accuracy: 0.4290 - val_loss: 1.0358
# Epoch 13/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4230 - loss: 1.0486 - val_accuracy: 0.4537 - val_loss: 1.0168
# Epoch 14/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4319 - loss: 1.0391 - val_accuracy: 0.4012 - val_loss: 1.0281
# Epoch 15/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4089 - loss: 1.0501 - val_accuracy: 0.4537 - val_loss: 1.0254
# Epoch 16/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4347 - loss: 1.0348 - val_accuracy: 0.4784 - val_loss: 1.0125
# Epoch 17/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4331 - loss: 1.0421 - val_accuracy: 0.3827 - val_loss: 1.0283
# Epoch 18/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4124 - loss: 1.0451 - val_accuracy: 0.4506 - val_loss: 1.0242
# Epoch 19/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4336 - loss: 1.0285 - val_accuracy: 0.4722 - val_loss: 1.0201
# Epoch 20/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4127 - loss: 1.0353 - val_accuracy: 0.4043 - val_loss: 1.0606
# Epoch 21/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4201 - loss: 1.0349 - val_accuracy: 0.4352 - val_loss: 1.0298
# Epoch 22/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4246 - loss: 1.0330 - val_accuracy: 0.4136 - val_loss: 1.0214
# Epoch 23/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4177 - loss: 1.0513 - val_accuracy: 0.4167 - val_loss: 1.0555
# Epoch 24/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4172 - loss: 1.0496 - val_accuracy: 0.4167 - val_loss: 1.0819
# Epoch 25/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4199 - loss: 1.0545 - val_accuracy: 0.4228 - val_loss: 1.0215
# Epoch 26/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4220 - loss: 1.0482 - val_accuracy: 0.4043 - val_loss: 1.0220
# Epoch 27/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4377 - loss: 1.0275 - val_accuracy: 0.4136 - val_loss: 1.0270
# Epoch 59/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4478 - loss: 1.0251 - val_accuracy: 0.4506 - val_loss: 1.0156
# Epoch 60/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4377 - loss: 1.0300 - val_accuracy: 0.4568 - val_loss: 1.0152
# Epoch 61/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4402 - loss: 1.0371 - val_accuracy: 0.4321 - val_loss: 1.0196
# Epoch 62/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4609 - loss: 1.0246 - val_accuracy: 0.4259 - val_loss: 1.0187
# Epoch 63/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4369 - loss: 1.0297 - val_accuracy: 0.4630 - val_loss: 1.0148
# Epoch 64/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4360 - loss: 1.0228 - val_accuracy: 0.4383 - val_loss: 1.0304
# Epoch 65/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4536 - loss: 1.0236 - val_accuracy: 0.4568 - val_loss: 1.0124
# Epoch 66/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4423 - loss: 1.0148 - val_accuracy: 0.4444 - val_loss: 1.0279
# Epoch 67/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4430 - loss: 1.0234 - val_accuracy: 0.4259 - val_loss: 1.0205
# Epoch 68/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4348 - loss: 1.0258 - val_accuracy: 0.4321 - val_loss: 1.0163
# Epoch 69/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4337 - loss: 1.0254 - val_accuracy: 0.4290 - val_loss: 1.0310
# Epoch 70/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4423 - loss: 1.0160 - val_accuracy: 0.4352 - val_loss: 1.0200
# Epoch 71/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4502 - loss: 1.0157 - val_accuracy: 0.4506 - val_loss: 1.0128
# Epoch 72/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4474 - loss: 1.0228 - val_accuracy: 0.4475 - val_loss: 1.0092
# Epoch 73/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4497 - loss: 1.0157 - val_accuracy: 0.4506 - val_loss: 1.0160
# Epoch 74/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4110 - loss: 1.0366 - val_accuracy: 0.4722 - val_loss: 1.0151
# Epoch 75/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4483 - loss: 1.0221 - val_accuracy: 0.4290 - val_loss: 1.0318
# Epoch 76/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4300 - loss: 1.0335 - val_accuracy: 0.4753 - val_loss: 1.0187
# Epoch 77/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4311 - loss: 1.0442 - val_accuracy: 0.4630 - val_loss: 1.0156
# Epoch 78/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4515 - loss: 1.0210 - val_accuracy: 0.4259 - val_loss: 1.0327
# Epoch 79/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4472 - loss: 1.0301 - val_accuracy: 0.4259 - val_loss: 1.0279
# Epoch 80/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4151 - loss: 1.0335 - val_accuracy: 0.4568 - val_loss: 1.0138
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4424 - loss: 1.0172
# Best Loss: 1.0159847736358643, Best Accuracy: 0.4614275395870209

# %%
print(f'Best Loss: {best_loss}, Best Accuracy: {best_accuracy}')
# Out:
# Best Loss: 1.0159847736358643, Best Accuracy: 0.4614275395870209

# %% [markdown]
# Checamos como está distribuido los datos. Esto hay que tenerlo en cuenta, dado que esta base de datos solo servirá para Engaged, Excited o Bored. El resto tendrá problemas grandes en localizarlo

# %%
# Obtener las predicciones del conjunto de validación
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Mostrar la precisión y pérdida del modelo
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Precisión del Modelo')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Pérdida del Modelo')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
# 7. Evaluar el modelo en el conjunto de pruebas
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step

# %%
# Calcular la precisión del modelo
accuracy = accuracy_score(y_test, y_pred_classes)
print("Precisión del modelo en el conjunto de pruebas:", accuracy)

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Mostrar la matriz de confusión de forma gráfica
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicción')
plt.ylabel('Etiqueta Verdadera')
plt.title('Matriz de Confusión')
plt.show()
print(label_encoder.classes_)
# Out:
# Precisión del modelo en el conjunto de pruebas: 0.46142754145638065
# ['bored' 'engaged' 'excited']

# %% [markdown]
# Guardamos el modelo.

# %%
# Guardar el modelo
best_model.save('modelo_mlp_Estratificado.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
